# %%
import sys

path='/home/jbohn/jupyter/personal/'
sys.path.append(f'{path}Adaptive_Signal_Estimation_Private')

from profiling.profiler import profile

# %%
from matrix_algorithms.difference_matrix  import test_lapack, test_pentapy, test_sparse

# %% [markdown]
# ### 100 x 100 system

# %%
profile(test_lapack,100)
# Out:
# Testing LU decomposition method
#          1447 function calls (1429 primitive calls) in 0.079 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.079    0.079 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:159(test_lapack)
#         1    0.062    0.062    0.062    0.062 {method 'dot' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.014    0.014 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    0.007    0.007 /home/jbohn/miniconda3/envs/research/lib/python3.10/site-packages/scipy/sparse/_base.py:400(dot)
#         1    0.000    0.000    0.007    0.007 /home/jbohn/miniconda3/envs/research/lib/python3.10/site-packages/scipy/sparse/_base.py:626(__matmul__)
# ...

# %%
profile(test_sparse,100)
# Out:
# Testing sparse method
#          1673 function calls (1664 primitive calls) in 0.075 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.075    0.075 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:174(test_sparse)
#         1    0.000    0.000    0.038    0.038 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    0.034    0.034 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:39(invert)
#         1    0.000    0.000    0.034    0.034 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:105(sparse_banded)
# ...

# %%
profile(test_pentapy,100)
# Out:
# Testing pentapy method
#          2466 function calls (2458 primitive calls) in 0.059 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.059    0.059 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:189(test_pentapy)
#         1    0.000    0.000    0.041    0.041 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    0.024    0.024 /home/jbohn/miniconda3/envs/research/lib/python3.10/site-packages/scipy/sparse/_base.py:400(dot)
#         1    0.000    0.000    0.024    0.024 /home/jbohn/miniconda3/envs/research/lib/python3.10/site-packages/scipy/sparse/_base.py:626(__matmul__)
#         1    0.000    0.000    0.024    0.024 /home/jbohn/miniconda3/envs/research/lib/python3.10/site-packages/scipy/sparse/_base.py:510(_mul_dispatch)
# ...

# %% [markdown]
# ### 1000 by 1000 system

# %%
profile(test_lapack,1000)
# Out:
# Testing LU decomposition method
#          1296 function calls (1288 primitive calls) in 0.841 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.841    0.841 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:159(test_lapack)
#         1    0.000    0.000    0.443    0.443 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    0.267    0.267 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:39(invert)
#         1    0.159    0.159    0.266    0.266 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:66(LU_decomposition)
#         1    0.207    0.207    0.207    0.207 {method 'dot' of 'numpy.ndarray' objects}
# ...

# %%
profile(test_sparse,1000)
# Out:
# Testing sparse method
#          1619 function calls (1610 primitive calls) in 0.607 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.607    0.607 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:174(test_sparse)
#         1    0.000    0.000    0.284    0.284 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    0.265    0.265 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:39(invert)
#         1    0.000    0.000    0.265    0.265 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:105(sparse_banded)
# ...

# %%
profile(test_pentapy,1000)
# Out:
# Testing pentapy method
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 profile(test_pentapy,1000)
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/profiling/profiler.py:11, in profile(fnc, n)
#       8 pr = cProfile.Profile()
#       9 pr.enable()
# ---> 11 fnc(n)
#      12 pr.disable()
#      13 ps = pstats.Stats(pr).sort_stats('cumulative')
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:199, in test_pentapy(n)
#     196 DDT_inv = D.DDT_inv
#     198 # check that the inverse is correct
# --> 199 assert np.allclose( DDT.dot(DDT_inv), np.eye(n-2), rtol=1e-8, atol=1e-8)
#     201 return
#
# AssertionError:

# %% [markdown]
# ### 2500 System

# %%
profile(test_lapack,2500)
# Out:
# Testing LU decomposition method
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 profile(test_lapack,2500)
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/profiling/profiler.py:11, in profile(fnc, n)
#       8 pr = cProfile.Profile()
#       9 pr.enable()
# ---> 11 fnc(n)
#      12 pr.disable()
#      13 ps = pstats.Stats(pr).sort_stats('cumulative')
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:169, in test_lapack(n)
#     166 DDT_inv = D.DDT_inv
#     168 # check that the inverse is correct
# --> 169 assert np.allclose( DDT.dot(DDT_inv), np.eye(n-2), rtol=1e-8, atol=1e-8)
#     171 return
#
# AssertionError:

# %%
profile(test_sparse,2500)
# Out:
# Testing sparse method
#          1560 function calls (1556 primitive calls) in 1.319 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.319    1.319 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:166(test_sparse)
#         1    0.000    0.000    1.319    1.319 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:9(__init__)
#         1    0.000    0.000    1.265    1.265 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:39(invert)
#         1    0.001    0.001    1.265    1.265 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:105(sparse_banded)
# ...

# %%
profile(test_pentapy,2500)
# Out:
# Testing pentapy method
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 profile(test_pentapy,2500)
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/profiling/profiler.py:11, in profile(fnc, n)
#       8 pr = cProfile.Profile()
#       9 pr.enable()
# ---> 11 fnc(n)
#      12 pr.disable()
#      13 ps = pstats.Stats(pr).sort_stats('cumulative')
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:199, in test_pentapy(n)
#     196 DDT_inv = D.DDT_inv
#     198 # check that the inverse is correct
# --> 199 assert np.allclose( DDT.dot(DDT_inv), np.eye(n-2), rtol=1e-8, atol=1e-8)
#     201 return
#
# AssertionError:

# %% [markdown]
# ### 10e3 x 10e3 system

# %%
profile(test_lapack,10000)
# Out:
# Testing LU decomposition method
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 profile(test_lapack,10000)
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/profiling/profiler.py:11, in profile(fnc, n)
#       8 pr = cProfile.Profile()
#       9 pr.enable()
# ---> 11 fnc(n)
#      12 pr.disable()
#      13 ps = pstats.Stats(pr).sort_stats('cumulative')
#
# File ~/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:169, in test_lapack(n)
#     166 DDT_inv = D.DDT_inv
#     168 # check that the inverse is correct
# --> 169 assert np.allclose( DDT.dot(DDT_inv), np.eye(n-2), rtol=1e-8, atol=1e-8)
#     171 return
#
# AssertionError:

# %%
profile(test_sparse,10000)
# Out:
# Testing sparse method
#          867 function calls (863 primitive calls) in 42.932 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   42.932   42.932 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:157(test_sparse)
#         1    0.000    0.000   42.929   42.929 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:12(__init__)
#         1    0.000    0.000   42.808   42.808 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:34(invert)
#         1    0.020    0.020   42.808   42.808 /home/jbohn/jupyter/personal/Adaptive_Signal_Estimation_Private/matrix_algorithms/difference_matrix.py:99(sparse_banded)
# ...

# %%
profile(test_pentapy,10000)
# Out:
# Testing pentapy method
