# %% [markdown]
# ### Investigation into High-Frequency Features and Targets
#
# https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4095405

# %%
! pip install ruptures

import ruptures as rpt  # our package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.api import VAR, ccf
import sys
import os
import logging

from datetime import datetime, timezone, timedelta
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller
from collections import deque


sys.path.append("/home/jovyan/data_warehouse/")
from dw_src.api.features_api import get_features_df, load_features
# Out:
# Collecting ruptures
#   Using cached ruptures-1.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from ruptures) (1.19.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (from ruptures) (1.5.2)
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.7

# %% [markdown]
# # Generate Features
#
# ### Book Features
# - Bid-Ask Spread (Variations)
# - LOB Imbalance
# - Midprice Returns
#
# ### Trade Features
# - Roll Measure ( covariance of returns )
# - Order Size Volume (Variations)
# - Kyle's Lambda  (Variations)
# - Order Size Imbalance
# - Order Side Imbalance
# - VPIN /PIN
#
# ### Targets
# - Bid-Ask Spread (Variations)
# - Returns (Sign and Size)
# - Transaction Duration

# %%
# Choose some features
features_to_load = [
    "spread_mean",
    "midprice_mean",
    "bbo_imbalance_mean",
    'trade_side_mean',# order side imbalance
    'trade_count',
    "Volume", # dollar volume
]

# Last 2 weeks
end = datetime.strptime("2022-8-2","%Y-%m-%d")
start= datetime.strptime("2022-5-1","%Y-%m-%d")

# Choose buckketing
time_agg = "5sec" # 1sec/5sec/10sec/30sec/60sec

df_data = load_features(
    "ftx", "BTCUSDP", time_agg, start, end, features_to_load
)
df_data.columns=[str(i+"_5") for i in df_data.columns]
df_data['Returns_5']=np.zeros(df_data.shape[0]) # many of these are zero as price doesn't always shift -> leads to illdefined correlations 
df_data['Returns_5']=pd.Series(df_data['midprice_mean_5'].pct_change(),index=df_data.index[1:])*100
df_data['Lambda_5']=df_data['Returns_5']/df_data['Volume_5'] # 5 second lookback which is our default here 

  
df_data['Roll_30']=2*np.sqrt(df_data['Returns_5'].rolling(6).cov(df_data['Returns_5'].shift(1).rolling(6)))
df_data

# %% [markdown]
# ### Generate Targets -> 5/30 Seconds
# Transaction Return
# - The average return of midprices over a future window
#
# Price Direction
# - Binary variable relating future window of returns to current (avg)
#
# Transaction Duration (TO:DO)
# - Amount of time required for some value of transactions/volume etc. to transact

# %%
df_data['Target_Return_5']=df_data['Returns_5'].shift(-1)
df_data['Target_Return_30']=df_data['Returns_5'].shift(-6)

df_data['Target_Price_Dir5']=(df_data['Target_Return_5']>df_data['Returns_5'].mean()).astype(int)

df_data['Target_Price_Dir30']=(df_data['Target_Return_30']>df_data['Returns_5'].mean()).astype(int)

# %%
#df_data.to_csv('lasso_cpd.csv')
df_data=pd.read_csv('/home/jovyan/personal/Changepoint_LOB/Lasso_OLS_CPD/btc_data/lasso_cpd.csv')
df_data['date']=[pd.to_datetime(i).round('60min') for i in df_data['timestamp']]

# %%
df_data
# Out:
#                         timestamp exchange_5 symbol_5  spread_mean_5  \
# 0       2022-05-01 00:01:00+00:00        ftx  BTCUSDP       1.237569
# 1       2022-05-01 00:01:05+00:00        ftx  BTCUSDP       1.164634
# 2       2022-05-01 00:01:10+00:00        ftx  BTCUSDP       1.076023
# 3       2022-05-01 00:01:15+00:00        ftx  BTCUSDP       1.016393
# 4       2022-05-01 00:01:20+00:00        ftx  BTCUSDP       1.117647
# ...                           ...        ...      ...            ...
# 793039  2022-08-01 23:59:05+00:00        ftx  BTCUSDP       1.000000
# 793040  2022-08-01 23:59:10+00:00        ftx  BTCUSDP       1.000000
# 793041  2022-08-01 23:59:15+00:00        ftx  BTCUSDP       1.011299
# 793042  2022-08-01 23:59:20+00:00        ftx  BTCUSDP       1.000000
# 793043  2022-08-01 23:59:25+00:00        ftx  BTCUSDP       1.000000
#
#         midprice_mean_5  bbo_imbalance_mean_5  trade_side_mean_5  \
# 0          37644.414365              0.403511           0.872727
# 1          37627.088415              0.149784           0.772727
# 2          37631.736842              0.593047           0.181818
# 3          37634.431694              0.168064           1.000000
# 4          37635.395425              0.283183           0.588235
# ...                 ...                   ...                ...
# 793039     23294.500000              0.096426           0.400000
# 793040     23294.500000              0.098081           1.000000
# 793041     23293.782486              0.195267           1.000000
# 793042     23292.193642              0.090106           0.941176
# 793043     23290.500000              0.168289           1.000000
#
#         trade_count_5  Volume_5  Returns_5  Lambda_5   Roll_30  \
# 0                55.0   12.4781  -0.026586 -0.002131  0.021322
# 1                22.0    0.8045  -0.046025 -0.057210  0.040481
# 2                22.0    2.0200   0.012354  0.006116  0.028232
# 3                14.0    0.6338   0.007161  0.011299  0.027470
# 4                34.0    3.8159   0.002561  0.000671  0.016942
# ...               ...       ...        ...       ...       ...
# 793039            5.0    1.5149  -0.005071 -0.003347  0.003199
# 793040            4.0    0.1206   0.000000  0.000000  0.002105
# 793041            9.0    0.6616  -0.003080 -0.004656  0.000951
# 793042           17.0    1.0871  -0.006821 -0.006274  0.001520
# 793043            7.0    0.5223  -0.007271 -0.013922  0.002693
#
#         Target_Return_5  Target_Return_30  Target_Price_Dir5  \
# 0             -0.046025         -0.000391                  0
# 1              0.012354         -0.000254                  1
# 2              0.007161          0.004588                  1
# 3              0.002561          0.000981                  1
# 4             -0.007302         -0.001916                  0
# ...                 ...               ...                ...
# 793039         0.000000         -0.007931                  1
# 793040        -0.003080         -0.005963                  0
# 793041        -0.006821         -0.019758                  0
# 793042        -0.007271          0.008540                  0
# 793043        -0.035007          0.000000                  0
#
#         Target_Price_Dir30                      date
# 0                        0 2022-05-01 00:00:00+00:00
# 1                        0 2022-05-01 00:00:00+00:00
# 2                        1 2022-05-01 00:00:00+00:00
# 3                        1 2022-05-01 00:00:00+00:00
# 4                        0 2022-05-01 00:00:00+00:00
# ...                    ...                       ...
# 793039                   0 2022-08-02 00:00:00+00:00
# 793040                   0 2022-08-02 00:00:00+00:00
# 793041                   0 2022-08-02 00:00:00+00:00
# 793042                   1 2022-08-02 00:00:00+00:00
# 793043                   1 2022-08-02 00:00:00+00:00
#
# [793044 rows x 17 columns]

# %% [markdown]
# # Fit a Penalized LASSO Model with cross validated alpha value for each target
#
# Note we are fitting the penalized model across our entire dataset, this is okay as we are not assessing predictability but instead analyzing an empirical relationship
#
# For each target we first standardize our feature set via normalization
#
# We then apply cross validation to optimally tune a LASSO model for each target
#
# ### Mean Return 5 seconds into Future

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

coeff_df=pd.DataFrame()

# %%
features= [ "bbo_imbalance_mean_5","trade_side_mean_5","trade_count_5","Volume_5","Returns_5","Lambda_5","Roll_30"] # All are 5 second lookback except for Roll -> Requires correlation on window 
targets=["Target_Return_5","Target_Return_30","Target_Price_Dir5","Target_Price_Dir30"]

# %%
df_data=df_data.dropna()
X_train, X_test, y_train, y_test = train_test_split(df_data[features],df_data['Target_Return_5'],train_size=0.99,random_state=100)

# %%
X_train
# Out:
#         bbo_imbalance_mean_5  trade_side_mean_5  trade_count_5  Volume_5  \
# 495628              0.333954           1.000000           11.0    3.7241
# 556912              0.169505           0.666667            3.0    0.0442
# 270513              0.458698           0.466667           45.0    9.4304
# 755641              0.545219           0.194444           36.0    6.8847
# 137880              0.257549           0.461538           13.0    2.7628
# ...                      ...                ...            ...       ...
# 212912              0.658780           0.000000            6.0    0.1543
# 65615               0.338384           0.555556           63.0   19.1482
# 778087              0.356276           0.818182           11.0    1.7923
# 210755              0.225570           0.333333            6.0    0.3742
# 56088               0.026080           0.000000            3.0    0.2253
#
#         Returns_5  Lambda_5   Roll_30
# 495628   0.000000  0.000000  0.004438
# 556912   0.000000  0.000000  0.003977
# 270513  -0.032280 -0.003423  0.017162
# 755641  -0.018186 -0.002642  0.019583
# 137880  -0.012008 -0.004346  0.023219
# ...           ...       ...       ...
# 212912   0.004969  0.032203  0.005059
# 65615   -0.050609 -0.002643  0.010784
# 778087  -0.008951 -0.004994  0.016742
# 210755   0.000000  0.000000  0.007575
# 56088   -0.009342 -0.041466  0.006749
#
# [785113 rows x 7 columns]

# %% [markdown]
# Let's normalize our data s.t. no individual feature overflows /skews the penalty
#
# This is very important in LASSO, otherwise it is possible for a noniformative feature to "drown" out informative features soley on magnitudes

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train=pd.DataFrame(scaler.transform(X_train))

scaler.fit(y_train.values.reshape(-1, 1))
y_train=scaler.transform(y_train.values.reshape(-1, 1))

# %%
model= linear_model.LassoCV( ) # here we use cross validated LASSO
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LassoCV()

# %%
coeffs=np.array(model.coef_) # optimal coefficients
coeff_df[0]=coeffs
for i,c in enumerate(coeffs):
    print(f"{features[i]} best estimate is {c} ")
# Out:
# bbo_imbalance_mean_5 best estimate is 0.09877378484350072
# trade_side_mean_5 best estimate is -0.20785894484594775
# trade_count_5 best estimate is -0.0
# Volume_5 best estimate is 0.008115472232871625
# Returns_5 best estimate is 0.16248938878015076
# Lambda_5 best estimate is -0.004426653220862099
# Roll_30 best estimate is -0.004902808080833241

# %%
model.alpha_
# Out:
# 0.002047921929041998

# %% [markdown]
# ### Mean Return 30 Seconds into Future

# %%
df_data=df_data.dropna()
X_train, X_test, y_train, y_test = train_test_split(df_data[features],df_data['Target_Return_30'],train_size=0.99,random_state=100)

# %%
X_train
# Out:
#         bbo_imbalance_mean_5  trade_side_mean_5  trade_count_5  Volume_5  \
# 495628              0.333954           1.000000           11.0    3.7241
# 556912              0.169505           0.666667            3.0    0.0442
# 270513              0.458698           0.466667           45.0    9.4304
# 755641              0.545219           0.194444           36.0    6.8847
# 137880              0.257549           0.461538           13.0    2.7628
# ...                      ...                ...            ...       ...
# 212912              0.658780           0.000000            6.0    0.1543
# 65615               0.338384           0.555556           63.0   19.1482
# 778087              0.356276           0.818182           11.0    1.7923
# 210755              0.225570           0.333333            6.0    0.3742
# 56088               0.026080           0.000000            3.0    0.2253
#
#         Returns_5  Lambda_5   Roll_30
# 495628   0.000000  0.000000  0.004438
# 556912   0.000000  0.000000  0.003977
# 270513  -0.032280 -0.003423  0.017162
# 755641  -0.018186 -0.002642  0.019583
# 137880  -0.012008 -0.004346  0.023219
# ...           ...       ...       ...
# 212912   0.004969  0.032203  0.005059
# 65615   -0.050609 -0.002643  0.010784
# 778087  -0.008951 -0.004994  0.016742
# 210755   0.000000  0.000000  0.007575
# 56088   -0.009342 -0.041466  0.006749
#
# [785113 rows x 7 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train=pd.DataFrame(scaler.transform(X_train))

scaler.fit(y_train.values.reshape(-1, 1))
y_train=scaler.transform(y_train.values.reshape(-1, 1))

# %%
model= linear_model.LassoCV( ) # here use an alpha penalty of 0.01
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LassoCV()

# %%
coeffs=np.array(model.coef_) # optimal coefficients
coeff_df[1]=coeffs
for i,c in enumerate(coeffs):
    print(f"{features[i]} best estimate is {c} ")
# Out:
# bbo_imbalance_mean_5 best estimate is 0.0008126724197633231
# trade_side_mean_5 best estimate is -0.0
# trade_count_5 best estimate is -0.0
# Volume_5 best estimate is -0.004394015180890244
# Returns_5 best estimate is -0.0
# Lambda_5 best estimate is -0.0
# Roll_30 best estimate is -0.0003302831059003389

# %%
model.alpha_
# Out:
# 0.0027229338179070215

# %% [markdown]
# ### Binary Price Direction of Mean Return 5 Seconds into Future

# %%
df_data=df_data.dropna()
X_train, X_test, y_train, y_test = train_test_split(df_data[features],df_data['Target_Price_Dir5'],train_size=0.99,random_state=100)

# %%
X_train
# Out:
#         bbo_imbalance_mean_5  trade_side_mean_5  trade_count_5  Volume_5  \
# 495628              0.333954           1.000000           11.0    3.7241
# 556912              0.169505           0.666667            3.0    0.0442
# 270513              0.458698           0.466667           45.0    9.4304
# 755641              0.545219           0.194444           36.0    6.8847
# 137880              0.257549           0.461538           13.0    2.7628
# ...                      ...                ...            ...       ...
# 212912              0.658780           0.000000            6.0    0.1543
# 65615               0.338384           0.555556           63.0   19.1482
# 778087              0.356276           0.818182           11.0    1.7923
# 210755              0.225570           0.333333            6.0    0.3742
# 56088               0.026080           0.000000            3.0    0.2253
#
#         Returns_5  Lambda_5   Roll_30
# 495628   0.000000  0.000000  0.004438
# 556912   0.000000  0.000000  0.003977
# 270513  -0.032280 -0.003423  0.017162
# 755641  -0.018186 -0.002642  0.019583
# 137880  -0.012008 -0.004346  0.023219
# ...           ...       ...       ...
# 212912   0.004969  0.032203  0.005059
# 65615   -0.050609 -0.002643  0.010784
# 778087  -0.008951 -0.004994  0.016742
# 210755   0.000000  0.000000  0.007575
# 56088   -0.009342 -0.041466  0.006749
#
# [785113 rows x 7 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train=pd.DataFrame(scaler.transform(X_train))

scaler.fit(y_train.values.reshape(-1, 1))
y_train=scaler.transform(y_train.values.reshape(-1, 1))

# %%
model= linear_model.LassoCV( ) # here use an alpha penalty of 0.01
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LassoCV()

# %%
coeffs=np.array(model.coef_) # optimal coefficients
coeff_df[2]=coeffs
for i,c in enumerate(coeffs):
    print(f"{features[i]} best estimate is {c} ")
# Out:
# bbo_imbalance_mean_5 best estimate is 0.21190393830373044
# trade_side_mean_5 best estimate is -0.2788777894680716
# trade_count_5 best estimate is -0.10445989242138543
# Volume_5 best estimate is 0.05290370695873499
# Returns_5 best estimate is 0.04320949356226214
# Lambda_5 best estimate is 0.0
# Roll_30 best estimate is -0.07897302801336478

# %%
model.alpha_
# Out:
# 0.00036824281219938383

# %% [markdown]
# ### Binary Price Direction of Mean Return 30 Seconds into Future

# %%
df_data=df_data.dropna()
X_train, X_test, y_train, y_test = train_test_split(df_data[features],df_data['Target_Price_Dir30'],train_size=0.99,random_state=100)

# %%
X_train
# Out:
#         bbo_imbalance_mean_5  trade_side_mean_5  trade_count_5  Volume_5  \
# 495628              0.333954           1.000000           11.0    3.7241
# 556912              0.169505           0.666667            3.0    0.0442
# 270513              0.458698           0.466667           45.0    9.4304
# 755641              0.545219           0.194444           36.0    6.8847
# 137880              0.257549           0.461538           13.0    2.7628
# ...                      ...                ...            ...       ...
# 212912              0.658780           0.000000            6.0    0.1543
# 65615               0.338384           0.555556           63.0   19.1482
# 778087              0.356276           0.818182           11.0    1.7923
# 210755              0.225570           0.333333            6.0    0.3742
# 56088               0.026080           0.000000            3.0    0.2253
#
#         Returns_5  Lambda_5   Roll_30
# 495628   0.000000  0.000000  0.004438
# 556912   0.000000  0.000000  0.003977
# 270513  -0.032280 -0.003423  0.017162
# 755641  -0.018186 -0.002642  0.019583
# 137880  -0.012008 -0.004346  0.023219
# ...           ...       ...       ...
# 212912   0.004969  0.032203  0.005059
# 65615   -0.050609 -0.002643  0.010784
# 778087  -0.008951 -0.004994  0.016742
# 210755   0.000000  0.000000  0.007575
# 56088   -0.009342 -0.041466  0.006749
#
# [785113 rows x 7 columns]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train=pd.DataFrame(scaler.transform(X_train))

scaler.fit(y_train.values.reshape(-1, 1))
y_train=scaler.transform(y_train.values.reshape(-1, 1))

# %%
model= linear_model.LassoCV( ) # here use an alpha penalty of 0.01
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LassoCV()

# %%
coeffs=np.array(model.coef_) # optimal coefficients
coeff_df[3]=coeffs
for i,c in enumerate(coeffs):
    print(f"{features[i]} best estimate is {c} ")
# Out:
# bbo_imbalance_mean_5 best estimate is 0.016913907195874024
# trade_side_mean_5 best estimate is -2.589940957516698e-05
# trade_count_5 best estimate is -0.060088394557969826
# Volume_5 best estimate is 0.02791960039850811
# Returns_5 best estimate is 8.636741187354922e-05
# Lambda_5 best estimate is -0.0008619673047514519
# Roll_30 best estimate is -0.08006895709283968

# %%
model.alpha_
# Out:
# 0.00022724672203386202

# %% [markdown]
# # Results
#
# ### LASSO with cross validated optimal alpha

# %%
coeff_df=coeff_df.T
coeff_df.columns=features
coeff_df.index=targets

# %%
sig_coeff_df=coeff_df[abs(coeff_df)>0.01].fillna(0)
sig_coeff_df
# Out:
#                     bbo_imbalance_mean_5  trade_side_mean_5  trade_count_5  \
# Target_Return_5                 0.098774          -0.207859       0.000000
# Target_Return_30                0.000000           0.000000       0.000000
# Target_Price_Dir5               0.211904          -0.278878      -0.104460
# Target_Price_Dir30              0.016914           0.000000      -0.060088
#
#                     Volume_5  Returns_5  Lambda_5   Roll_30
# Target_Return_5     0.000000   0.162489       0.0  0.000000
# Target_Return_30    0.000000   0.000000       0.0  0.000000
# Target_Price_Dir5   0.052904   0.043209       0.0 -0.078973
# Target_Price_Dir30  0.027920   0.000000       0.0 -0.080069

# %% [markdown]
# ### Daily Ordinary Least Squares Model for significant variables
#
# We are particularly interested to see if there is a changepoint pattern across optimal betas
#
# This would support our results about changes between empirical relationships

# %%
sig_features={}
var_features={}
for x,row in sig_coeff_df.iterrows():
    
    sig_features[x]=row[abs(row)>0.01].index.values
    var_features[x]=[f"{i}_var" for i in row[abs(row)>0.01].index.values]
sig_features
# Out:
# {'Target_Return_5': array(['bbo_imbalance_mean_5', 'trade_side_mean_5', 'Returns_5'],
#        dtype=object),
#  'Target_Return_30': array([], dtype=object),
#  'Target_Price_Dir5': array(['bbo_imbalance_mean_5', 'trade_side_mean_5', 'trade_count_5',
#         'Volume_5', 'Returns_5', 'Roll_30'], dtype=object),
#  'Target_Price_Dir30': array(['bbo_imbalance_mean_5', 'trade_count_5', 'Volume_5', 'Roll_30'],
#        dtype=object)}

# %%
#df_data['date']=[i.date() for i in df_data.index]
days=np.unique(np.array([i  for i in df_data['date']]))

coeff={}
resid={}
sample_var={}
for j in sig_features.keys(): 
    if len(sig_features[j])==0:
        continue
    coeff[j]=np.array([])
    resid[j]=np.array([])
    sample_var[j]=np.array([])
    for i in days:
    
        subset=df_data[df_data['date']==i]
        
        X_train, X_test, y_train, y_test =train_test_split(subset[sig_features[j]],subset[j],train_size=0.99,random_state=100)
        model=linear_model.LinearRegression()
        model.fit(X_train,y_train)
        residuals=np.linalg.norm(y_train - model.predict(X_train)) ** 2 # compute the residuals of the fit
        features_sample_var=X_train.var(axis=0)
        
        coeff[j]=np.append(coeff[j],np.array(model.coef_))
        resid[j]=np.append(resid[j],np.array(residuals))
        sample_var[j]=np.append(sample_var[j],np.array(features_sample_var))

# %% [markdown]
# ### Mean Return 5 seconds into Future

# %%
mean_return_beta=pd.DataFrame(coeff['Target_Return_5'].reshape(2114,3),columns=sig_features['Target_Return_5'])
mean_return_beta['residuals']=resid['Target_Return_5']
mean_return_beta[var_features['Target_Return_5']]=sample_var['Target_Return_5'].reshape(2114,3)

fig,ax=plt.subplots(3,1,figsize=(14,10))
ax[0].set_title("BTCUSP Mean Return 5 Seconds Future")
ax[0].plot(mean_return_beta['bbo_imbalance_mean_5'],label='bbo_imbalance_mean_5')
ax[1].plot(mean_return_beta['trade_side_mean_5'],color='red',label='trade_side_mean_5')
ax[2].plot(mean_return_beta['Returns_5'],color='green',label='Returns_5')
ax[0].set_xlabel("May-August 2022")
ax[1].set_xlabel("May-August 2022")
ax[2].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
mean_dir_return_beta=pd.DataFrame(coeff['Target_Price_Dir5'].reshape(2114,6),columns=sig_features['Target_Price_Dir5'])
mean_dir_return_beta['residuals']=resid['Target_Price_Dir5']
mean_dir_return_beta[var_features['Target_Price_Dir5']]=sample_var['Target_Price_Dir5'].reshape(2114,6)

fig,ax=plt.subplots(6,1,figsize=(14,10))
ax[0].set_title(" BTCUSDP Price Direction 5 Seconds Future")
ax[0].plot(mean_dir_return_beta['bbo_imbalance_mean_5'],label='bbo_imbalance_mean_5')
ax[1].plot(mean_dir_return_beta['trade_side_mean_5'],color='red',label='trade_side_mean_5')
ax[2].plot(mean_dir_return_beta['trade_count_5'],color='green',label='trade_count_5')
ax[3].plot(mean_dir_return_beta['Volume_5'],color='orange',label='Volume_5')
ax[4].plot(mean_dir_return_beta['Roll_30'],color='purple',label='Roll_30')
ax[5].plot(mean_return_beta['Returns_5'],color='pink',label='Returns_5')

ax[5].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[3].set_ylabel("LS Beta Estimate ")
ax[4].set_ylabel("LS Beta Estimate ")
ax[5].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
ax[4].legend()
ax[5].legend()

# %%
price_dir_30_beta=pd.DataFrame(coeff['Target_Price_Dir30'].reshape(2114,4),columns=sig_features['Target_Price_Dir30'])
price_dir_30_beta['residuals']=resid['Target_Price_Dir30']
price_dir_30_beta[var_features['Target_Price_Dir30']]=sample_var['Target_Price_Dir30'].reshape(2114,4)

fig,ax=plt.subplots(4,1,figsize=(14,10))
ax[0].set_title("Price Direction 30 Seconds Future")
ax[0].plot(price_dir_30_beta['trade_count_5'],label='trade_count_5')
ax[1].plot(price_dir_30_beta['Roll_30'],color='red',label='Roll_30')
ax[2].plot(price_dir_30_beta['bbo_imbalance_mean_5'],color='orange',label='bbo_imbalance_mean_5')
ax[3].plot(price_dir_30_beta['Volume_5'],color='green',label='Volume_5')
ax[0].set_xlabel("May-August 2022")
ax[1].set_xlabel("May-August 2022")
ax[2].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[3].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

# %%
mean_return_beta.to_csv('/home/jovyan/personal/Changepoint_LOB/Lasso_OLS_CPD/btc_data/mean_return_beta.csv')
mean_dir_return_beta.to_csv('/home/jovyan/personal/Changepoint_LOB/Lasso_OLS_CPD/btc_data/mean_dir_return_beta.csv')
price_dir_30_beta.to_csv('/home/jovyan/personal/Changepoint_LOB/Lasso_OLS_CPD/btc_data/price_dir_30_beta.csv')

# %% [markdown]
# ### Changepoint Analysis :
#
# We will be implementing Dynamic Programming for now to detect 10 changepoints  in our estimates for Least Squares Coefficients across time. Empirically the variance of our estimates seem to follow a changepoint proicess . Note as the feature set stays consistent across time this assumes a piecewise constant process in the latent covariance matrix of our feature matrix
#
# From empirical analysis, the variance of our estimators exhibit a changepoint process in their variance. We know the variance of our estimators are a function of the true error variance and each variable's variance. Assuming true error variance to be consistent, our results imply a changepoint process in the variance values of our features
#
# Apply a pruning step where our cost function is mse and Cross-Validation or method specific tuning needs to be applied on  penalty coeficient

# %%
def compute_cp(signal,bkps,min_size,jump):
    model = "l2"  # mse cost between observed 
    algo = rpt.Dynp(model=model, min_size=min_size, jump=jump).fit(signal.values)
    
    my_bkps = algo.predict(n_bkps=bkps)
    

            
    return my_bkps

# %%
features=[mean_return_beta['bbo_imbalance_mean_5'],mean_return_beta['Returns_5'],mean_return_beta['trade_side_mean_5'],mean_return_beta['Returns_5'],mean_dir_return_beta['bbo_imbalance_mean_5'],mean_dir_return_beta['trade_side_mean_5'],mean_dir_return_beta['trade_count_5'],mean_dir_return_beta['Volume_5'],mean_dir_return_beta['Roll_30'],price_dir_30_beta['trade_count_5'],price_dir_30_beta['bbo_imbalance_mean_5'],price_dir_30_beta['Volume_5'],price_dir_30_beta['Roll_30']]
num_bkps=10
min_size=50 # 5 days between changepoints
jump=2# every candidate point is considered 

bkps_feat={}
for j,i in enumerate(features):
     
    bkps=compute_cp(i,num_bkps,min_size,jump)
    bkps_feat[str(i.name+f"_{j}")]=np.array(bkps)
    if len(bkps)>0:
        
        print(i.name,j,bkps)
# Out:
# bbo_imbalance_mean_5 0 [198, 248, 298, 378, 478, 878, 1010, 1080, 1148, 1216, 2114]
# Returns_5 1 [92, 170, 332, 476, 538, 844, 1188, 1314, 1514, 1766, 2114]
# trade_side_mean_5 2 [196, 246, 296, 476, 1008, 1078, 1136, 1250, 1776, 1826, 2114]
# Returns_5 3 [92, 170, 332, 476, 538, 844, 1188, 1314, 1514, 1766, 2114]
# bbo_imbalance_mean_5 4 [412, 622, 676, 740, 832, 1206, 1256, 1526, 1772, 1822, 2114]
# trade_side_mean_5 5 [202, 308, 626, 676, 1008, 1078, 1248, 1698, 1758, 1822, 2114]
# trade_count_5 6 [164, 478, 534, 632, 684, 792, 842, 912, 970, 1290, 2114]
# Volume_5 7 [310, 420, 476, 532, 792, 858, 912, 970, 1540, 1644, 2114]
# Roll_30 8 [74, 166, 482, 534, 622, 672, 790, 840, 988, 1274, 2114]
# trade_count_5 9 [180, 268, 870, 924, 988, 1126, 1318, 1616, 1666, 1974, 2114]
# bbo_imbalance_mean_5 10 [262, 344, 620, 754, 810, 866, 990, 1070, 1120, 1184, 2114]
# Volume_5 11 [160, 308, 378, 504, 554, 606, 1352, 1402, 1582, 1900, 2114]
# Roll_30 12 [74, 166, 484, 540, 620, 788, 840, 972, 1312, 1414, 2114]

# %%
fig,ax=plt.subplots(3,1,figsize=(14,10))
ax[0].set_title("Mean Return 5 Seconds Future")
ax[0].vlines(mean_return_beta.index[bkps_feat['bbo_imbalance_mean_5_0']-1],min(mean_return_beta['bbo_imbalance_mean_5'].values),max(mean_return_beta['bbo_imbalance_mean_5'].values),color='black',lw=2.5)
ax[0].plot(mean_return_beta['bbo_imbalance_mean_5'],label='bbo_imbalance_mean_5')

ax[1].plot(mean_return_beta['trade_side_mean_5'],color='red',label='trade_side_mean_5')
ax[1].vlines(mean_return_beta.index[bkps_feat['trade_side_mean_5_2']-1],min(mean_return_beta['trade_side_mean_5'].values),max(mean_return_beta['trade_side_mean_5'].values),color='black',lw=2.5)

ax[2].plot(mean_return_beta['Returns_5'],color='green',label='Returns_5')
ax[2].scatter(mean_return_beta.index[bkps_feat['Returns_5_1']-1],mean_return_beta['Returns_5'].values[bkps_feat['Returns_5_1']-1],color='black',s=50)
ax[2].vlines(mean_return_beta.index[bkps_feat['Returns_5_1']-1],min(mean_return_beta['Returns_5'].values),max(mean_return_beta['Returns_5'].values),color='black',lw=2.5)

ax[0].set_xlabel("May-August 2022")
ax[1].set_xlabel("May-August 2022")
ax[2].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
fig,ax=plt.subplots(6,1,figsize=(14,14))
ax[0].set_title("Price Direction 5 Seconds Future")
ax[0].plot(mean_dir_return_beta['bbo_imbalance_mean_5'],label='bbo_imbalance_mean_5',lw=1)
ax[0].scatter(mean_dir_return_beta.index[bkps_feat['bbo_imbalance_mean_5_4']-1],mean_dir_return_beta['bbo_imbalance_mean_5'].values[bkps_feat['bbo_imbalance_mean_5_4']-1],color='black',s=50)
ax[0].vlines(mean_dir_return_beta.index[bkps_feat['bbo_imbalance_mean_5_4']-1],min(mean_dir_return_beta['bbo_imbalance_mean_5'].values),max(mean_dir_return_beta['bbo_imbalance_mean_5'].values),color='black',lw=2.5)

ax[1].plot(mean_dir_return_beta['trade_side_mean_5'],color='red',label='trade_side_mean_5',lw=1)
ax[1].vlines(mean_dir_return_beta.index[bkps_feat['trade_side_mean_5_5']-1],min(mean_dir_return_beta['trade_side_mean_5'].values),max(mean_dir_return_beta['trade_side_mean_5'].values),color='black',lw=2.5)


ax[2].plot(mean_dir_return_beta['trade_count_5'],color='green',label='trade_count_5')
ax[2].vlines(mean_dir_return_beta.index[bkps_feat['trade_count_5_6']-1],min(mean_dir_return_beta['trade_count_5'].values),max(mean_dir_return_beta['trade_count_5'].values),color='black',lw=2.5)


ax[3].plot(mean_dir_return_beta['Volume_5'],color='orange',label='Volume_5')
ax[3].vlines(mean_dir_return_beta.index[bkps_feat['Volume_5_7']-1],min(mean_dir_return_beta['Volume_5'].values),max(mean_dir_return_beta['Volume_5'].values),color='black',lw=2.5)


ax[4].plot(mean_dir_return_beta['Roll_30'],color='purple',label='Roll_30')
ax[4].vlines(mean_dir_return_beta.index[bkps_feat['Roll_30_8']-1],min(mean_dir_return_beta['Roll_30'].values),max(mean_dir_return_beta['Roll_30'].values),color='black',lw=2.5)


ax[5].plot(mean_dir_return_beta['Returns_5'],color='pink',label='Returns_5')
ax[5].vlines(mean_dir_return_beta.index[bkps_feat['Returns_5_3']-1],min(mean_dir_return_beta['Returns_5'].values),max(mean_dir_return_beta['Returns_5'].values),color='black',lw=2.5)



ax[5].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[3].set_ylabel("LS Beta Estimate ")
ax[4].set_ylabel("LS Beta Estimate ")
ax[5].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
ax[4].legend()
ax[5].legend()

# %%
fig,ax=plt.subplots(4,1,figsize=(14,10))
ax[0].set_title("Price Direction 30 Seconds Future")
ax[0].plot(price_dir_30_beta['trade_count_5'],label='trade_count_5')
ax[0].vlines(price_dir_30_beta.index[bkps_feat['trade_count_5_9']-1],min(price_dir_30_beta['trade_count_5'].values),max(price_dir_30_beta['trade_count_5'].values),color='black',lw=2.5)


ax[1].plot(price_dir_30_beta['Roll_30'],color='red',label='Roll_30')
ax[1].vlines(price_dir_30_beta.index[bkps_feat['Roll_30_12']-1],min(price_dir_30_beta['Roll_30'].values),max(price_dir_30_beta['Roll_30'].values),color='black',lw=2.5)


ax[2].plot(price_dir_30_beta['bbo_imbalance_mean_5'],color='orange',label='bbo_imbalance_mean_5')
ax[2].vlines(price_dir_30_beta.index[bkps_feat['bbo_imbalance_mean_5_10']-1],min(price_dir_30_beta['bbo_imbalance_mean_5'].values),max(price_dir_30_beta['bbo_imbalance_mean_5'].values),color='black',lw=2.5)


ax[3].plot(price_dir_30_beta['Volume_5'],color='green',label='Volume_5')
ax[3].vlines(price_dir_30_beta.index[bkps_feat['Volume_5_11']-1],min(price_dir_30_beta['Volume_5'].values),max(price_dir_30_beta['Volume_5'].values),color='black',lw=2.5)


ax[0].set_xlabel("May-August 2022")
ax[1].set_xlabel("May-August 2022")
ax[2].set_xlabel("May-August 2022")
ax[0].set_ylabel("LS Beta Estimate ")
ax[1].set_ylabel("LS Beta Estimate ")
ax[2].set_ylabel("LS Beta Estimate ")
ax[3].set_ylabel("LS Beta Estimate ")
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()

# %% [markdown]
# ### Cross Comparison of Chanepoints

# %%
plt.figure(figsize=(16,12))
for sym,bkps in bkps_feat.items():
    
    plt.plot(bkps,label=str(sym),marker='*')
    plt.legend()

# %% [markdown]
# ### Metrics for Defining how close changepoint estimations are
